# %% [markdown]
# # Decision Tree ID3

# %%
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

# %%
def entropy(y):
    classes, counts = np.unique(y, return_counts=True)
    probs = counts / counts.sum()
    return -np.sum(probs * np.log2(probs))

def information_gain(X_column, y):
    total_entropy = entropy(y)
    values, counts = np.unique(X_column, return_counts=True)
    weighted_entropy = 0
    for v, c in zip(values, counts):
        y_sub = y[X_column == v]
        weighted_entropy += (c / len(y)) * entropy(y_sub)
    return total_entropy - weighted_entropy

# %%
# Node structure to sotre necessary attributes required for ploting
class Node:
    def __init__(self, feature=None, children=None, label=None, entries=None, gain=None, node_entropy=None):
        self.feature = feature
        self.children = children
        self.label = label
        self.entries = entries  # indices of dataset at this node
        self.gain = gain
        self.entropy = node_entropy
        self.width = None  # for plotting

# %%
# ID3 algorithm builds a decision tree by selecting the feature with the highest
# information gain at each step. It creates leaf nodes when all samples belong
# to the same class or when no features remain, and recursively splits data
# based on feature values to grow the tree.

def id3(X, y, features, indices=None):
    if indices is None:
        indices = np.arange(len(y))
    y_subset = y[indices]

    # Leaf if all same class
    if len(np.unique(y_subset)) == 1:
        return Node(label=y_subset[0], entries=list(indices), node_entropy=entropy(y_subset))

    # Leaf if no features left
    if len(features) == 0:
        majority = Counter(y_subset).most_common(1)[0][0]
        return Node(label=majority, entries=list(indices), node_entropy=entropy(y_subset))

    # Compute info gain for each feature
    gains = [information_gain(X[indices, f], y_subset) for f in features]
    best_feature = features[np.argmax(gains)]
    best_gain = gains[np.argmax(gains)]

    node = Node(feature=best_feature, children={}, entries=list(indices), gain=best_gain, node_entropy=entropy(y_subset))

    for value in np.unique(X[indices, best_feature]):
        child_idx = indices[X[indices, best_feature] == value]
        remaining_features = [f for f in features if f != best_feature]
        node.children[value] = id3(X, y, remaining_features, child_idx)

    return node

# %%
features_names = ['Outlook', 'Temperature', 'Humidity', 'Wind']
data = [
    ['Sunny','Hot','High','Weak','No'],
    ['Sunny','Hot','High','Strong','No'],
    ['Overcast','Hot','High','Weak','Yes'],
    ['Rain','Mild','High','Weak','Yes'],
    ['Rain','Cool','Normal','Weak','Yes'],
    ['Rain','Cool','Normal','Strong','No'],
    ['Overcast','Cool','Normal','Strong','Yes'],
    ['Sunny','Mild','High','Weak','No'],
    ['Sunny','Cool','Normal','Weak','Yes'],
    ['Rain','Mild','Normal','Weak','Yes'],
    ['Sunny','Mild','Normal','Strong','Yes'],
    ['Overcast','Mild','High','Strong','Yes'],
    ['Overcast','Hot','Normal','Weak','Yes'],
    ['Rain','Mild','High','Strong','No']
]


data = np.array(data)
X = data[:, :4]
y = data[:, 4]

# %%
# Map categorical features to numeric
feature_maps = []
X_num = np.zeros(X.shape, dtype=int)
for i in range(X.shape[1]):
    uniq = np.unique(X[:, i])
    feature_maps.append({v: idx for idx, v in enumerate(uniq)})
    X_num[:, i] = [feature_maps[i][v] for v in X[:, i]]

target_map = {'No':0, 'Yes':1}
y_num = np.array([target_map[v] for v in y])

features = list(range(X_num.shape[1]))
tree = id3(X_num, y_num, features)

# %%
# Compute subtree width (to avoid overlap)

def compute_subtree_width(node):
    if node.label is not None:
        node.width = 1
    else:
        node.width = sum(compute_subtree_width(child) for child in node.children.values())
    return node.width

compute_subtree_width(tree)
# Out:
# 5

# %%
# Tree Plotting with entries, gain, entropy

def plot_tree(node, x=0, y=0, dx=0, dy=1.5, ax=None, parent_coord=None, edge_label=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(14,8))
        ax.set_axis_off()

    # Node label with entries, entropy, gain
    if node.label is not None:
        label = f"Label: {['No','Yes'][node.label]}\nEntries: {node.entries}\nEntropy: {node.entropy:.2f}"
        color = 'lightcoral' if node.label==0 else 'lightgreen'
    else:
        label = f"{features_names[node.feature]}\nEntries: {node.entries}\nEntropy: {node.entropy:.2f}\nGain: {node.gain:.2f}"
        color = 'lightblue'

    ax.text(x, y, label, ha='center', va='center',
            bbox=dict(boxstyle="round,pad=0.3", facecolor=color, edgecolor='k'))

    # Draw edge from parent
    if parent_coord is not None:
        ax.plot([parent_coord[0], x], [parent_coord[1], y], 'k-')
        if edge_label is not None:
            ax.text((parent_coord[0]+x)/2, (parent_coord[1]+y)/2, edge_label, ha='center', va='center', backgroundcolor='w')

    # Recursively plot children
    if node.children:
        start_x = x - node.width/2
        for val, child in node.children.items():
            child_x = start_x + child.width/2
            child_y = y - dy
            edge_val_label = list(feature_maps[node.feature].keys())[val]
            plot_tree(child, x=child_x, y=child_y, dx=dx/2, dy=dy, ax=ax, parent_coord=(x,y), edge_label=edge_val_label)
            start_x += child.width

    return ax

ax = plot_tree(tree)
plt.title("ID3 Decision Tree for Tennis Dataset\n", fontsize=14)
plt.show()
